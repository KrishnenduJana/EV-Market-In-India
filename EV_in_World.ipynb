# %%
import pandas as pd

# %%
df = pd.read_csv("Data/IEA-EV-dataEV salesCarsHistorical.csv")

# %%
df.head()
# Out:
#       region    category parameter  mode powertrain  year      unit  value
# 0  Australia  Historical  EV sales  Cars        BEV  2011  Vehicles     49
# 1  Australia  Historical  EV sales  Cars        BEV  2012  Vehicles    170
# 2  Australia  Historical  EV sales  Cars       PHEV  2012  Vehicles     80
# 3  Australia  Historical  EV sales  Cars       PHEV  2013  Vehicles    100
# 4  Australia  Historical  EV sales  Cars        BEV  2013  Vehicles    190

# %%
df1 = df.sort_values("year")

# %%
df1
# Out:
#           region    category parameter  mode powertrain  year      unit  \
# 183         EU27  Historical  EV sales  Cars        BEV  2010  Vehicles
# 436        Korea  Historical  EV sales  Cars        BEV  2010  Vehicles
# 689       Sweden  Historical  EV sales  Cars        BEV  2010  Vehicles
# 41       Belgium  Historical  EV sales  Cars        BEV  2010  Vehicles
# 411        Japan  Historical  EV sales  Cars        BEV  2010  Vehicles
# ..           ...         ...       ...   ...        ...   ...       ...
# 86        Brazil  Historical  EV sales  Cars       PHEV  2022  Vehicles
# 87        Brazil  Historical  EV sales  Cars        BEV  2022  Vehicles
# 501  Netherlands  Historical  EV sales  Cars        BEV  2022  Vehicles
# 620     Portugal  Historical  EV sales  Cars       PHEV  2022  Vehicles
# 833        World  Historical  EV sales  Cars       PHEV  2022  Vehicles
#
#        value
# 183     1400
# 436       61
# 689        4
# 41        48
# 411     2400
# ..       ...
# 86     10000
# 87      8500
# 501    73000
# 620    16000
# 833  2900000
#
# [834 rows x 8 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.kdeplot(data=df, x="year")
# Out:
# <AxesSubplot: xlabel='year', ylabel='Density'>

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=df, x="year")
# Out:
# <AxesSubplot: xlabel='year', ylabel='count'>

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=penguins, x="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Count'>

# %%
df1=df.sort_values("year")
plt.figure(figsize=(20,8))
sns.histplot(data=df, x="region", hue="year")
# Out:
# <AxesSubplot: xlabel='region', ylabel='Count'>
