# %% [markdown]
# # Scooter EDA

# %%
import pandas as pd
from matplotlib.pyplot import pie, axis, show

# %%
df = pd.read_excel("Data/Cycle_Cleaned1.xlsx")

# %%
print(df.head())
# Out:
#                 Model     Brand  Price  Power(kwh)  Mileage(km)
# 0        Motovolt Hum  Motovolt  31049       0.216           30
# 1        Motovolt Ice  Motovolt  28449       0.216           30
# 2       Motovolt Kivo  Motovolt  29774       0.576           30
# 3  Motovolt Kivo Easy  Motovolt  29774       0.576           30
# 4         EMotorad X3  EMotorad  32999       0.208           25

# %%
df.drop(df.iloc[:, 5:19], inplace=True, axis=1)

# %%
print(df.head())
# Out:
#                 Model     Brand  Price  Power(kwh)  Mileage(km)
# 0        Motovolt Hum  Motovolt  31049       0.216           30
# 1        Motovolt Ice  Motovolt  28449       0.216           30
# 2       Motovolt Kivo  Motovolt  29774       0.576           30
# 3  Motovolt Kivo Easy  Motovolt  29774       0.576           30
# 4         EMotorad X3  EMotorad  32999       0.208           25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Model        46 non-null     object
#  1   Brand        46 non-null     object
#  2   Price        46 non-null     int64
#  3   Power(kwh)   46 non-null     float64
#  4   Mileage(km)  46 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.9+ KB

# %%
df.describe()
# Out:
#                Price  Power(kwh)  Mileage(km)
# count      46.000000   46.000000    46.000000
# mean    62740.282609    1.156677    53.413043
# std     93127.961379    4.406559    37.760400
# min     24999.000000    0.042640    25.000000
# 25%     32999.000000    0.229320    30.000000
# 50%     39999.000000    0.355000    33.500000
# 75%     49174.750000    0.549600    73.750000
# max    500000.000000   30.240000   180.000000

# %%
df.groupby('Brand').size().plot(kind='pie', autopct='%.1f')
# Out:
# <AxesSubplot: >

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
sns.displot(df['Price'], kde=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
colors = ['grey' if (s < max(df['Price'])) else 'red' for s in df['Price']]

# %%
sorted_df = df.sort_values('Price')
print(sorted_df)
# Out:
#                        Model     Brand   Price  Power(kwh)  Mileage(km)
# 10               EMotorad X1  EMotorad   24999     0.27540           40
# 45               EMotorad X2  EMotorad   27999     1.95000           25
# 1               Motovolt Ice  Motovolt   28449     0.21600           30
# 41            Hero Lectro H3      Hero   28499     1.45000           30
# 21            Hero Lectro C3      Hero   28999     0.20880           30
# 2              Motovolt Kivo  Motovolt   29774     0.57600           30
# 3         Motovolt Kivo Easy  Motovolt   29774     0.57600           30
# 31          Motovolt Kivo 24  Motovolt   29774    30.24000           25
# 42            Hero Lectro H5      Hero   29999     1.45000           30
# 22            Hero Lectro C5      Hero   30999     0.20880           30
# 0               Motovolt Hum  Motovolt   31049     0.21600           30
# 4                EMotorad X3  EMotorad   32999     0.20800           25
# ...

# %%
import matplotlib.pyplot as plt

sorted_df = df.sort_values('Price')

fig = plt.figure(figsize=(22, 10))
plt.bar(sorted_df['Brand'], sorted_df['Price'], width=0.5)

# average_price = sorted_df['Price'].mean()
# plt.axhline(average_price, color='r', linestyle='--', linewidth=2)

plt.xlabel("Brand")
plt.ylabel("Price")
plt.title("Brand vs Price")
plt.xticks(rotation=90)  # Rotating x-axis labels for better readability
plt.show()

# %%
fig = plt.figure(figsize = (22, 10))
plt.bar(df['Brand'], df['Price'], color =colors,width = 0.5)

average_price = df['Price'].mean()
plt.axhline(average_price, color='r', linestyle='--', linewidth=2)
 
plt.xlabel("Brand")
plt.ylabel("Price")
plt.title("Brand vs Price")
plt.xticks(rotation=90)  # Rotating x-axis labels for better readability
plt.show()

# %%
top_mileage = df['Mileage(km)']
colors = ['grey' if (s < max(top_mileage)) else 'red' for s in top_mileage]

# %%
import matplotlib.pyplot as plt
df = df.sort_values("Mileage(km)")

fig = plt.figure(figsize=(22, 10))
plt.bar(df['Brand'], df['Mileage(km)'], color=colors, width=0.5)

average_mileage = df['Mileage(km)'].mean()
plt.axhline(average_mileage, color='r', linestyle='--', linewidth=2)

plt.xlabel("Brand")
plt.ylabel("Mileage(km)")
plt.title("Brand vs Mileage")
plt.show()

# %%
# importing the modules
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
highest_car = df['Brand'].value_counts().index
plt.figure(figsize=(20, 8))
sns.countplot(data=df, x="Brand", order=highest_car)
# Out:
# <AxesSubplot: xlabel='Brand', ylabel='count'>

# %%
sns.pairplot(df, diag_kind="hist")

# %%
plt.figure(figsize=(20, 8))
sns.histplot(data=df,x = "Brand", y="Power(kwh)", binwidth=2)
# Out:
# <AxesSubplot: xlabel='Brand', ylabel='Power(kwh)'>

# %%
plt.figure(figsize=(20, 8))
# Sort the DataFrame by 'Price' column in ascending order
sorted_df = df.sort_values('Price')

# Plotting the barplot
sns.barplot(data=sorted_df, x="Brand", y="Price")
plt.xlabel('Brand')
plt.ylabel('Price')
plt.title('Barplot (Ascending Order)')
plt.show()

# %%
max_prices = df.groupby('Brand')['Price'].max()

# %%
max_prices = df.groupby('Brand')['Price'].mean().reset_index()
sorted_max_prices = max_prices.sort_values('Price')

# %%
plt.figure(figsize=(20, 8))
sns.barplot(data=max_prices, x='Brand', y='Price')
plt.xlabel('Brand')
plt.ylabel('Mean Price')
plt.title('Mean Price for Each Brand')
plt.show()

# %%
max_prices = df.groupby('Brand')['Price'].max()

# Sort maximum prices in ascending order
sorted_prices = max_prices.sort_values()

# Plotting histogram for maximum prices in ascending order
plt.hist(sorted_prices, bins='auto', edgecolor='black')
plt.xlabel('Maximum Price')
plt.ylabel('Frequency')
plt.title('Histogram of Maximum Price for Each Brand (Ascending Order)')
plt.show()

# %%
plt.figure(figsize=(20, 8))
result = df.groupby(["Brand"])['Price'].aggregate(np.median).reset_index().sort_values('Price')
sns.barplot(x='Brand', y="Price", data=df, order=result['Brand']) #formerly: sns.barplot(x='Id', y="Speed", data=df, palette=colors, order=result['Id'])
plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.barplot(data=df,x = "Brand", y="Power(kwh)")
# Out:
# <AxesSubplot: xlabel='Brand', ylabel='Power(kwh)'>

# %%
plt.figure(figsize=(20, 8))
# Plotting histogram for Price in ascending order
sorted_price = df['Price'].sort_values()
plt.hist(sorted_price, bins='auto', edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram for Price (Ascending Order)')
plt.show()

# Plotting bar plot for Brand in ascending order
plt.figure(figsize=(20, 8))
sorted_brand = df['Brand'].value_counts().sort_index()
plt.bar(sorted_brand.index, sorted_brand)
plt.xlabel('Brand')
plt.ylabel('Count')
plt.title('Bar Plot for Brand (Ascending Order)')
plt.show()

# %%
data1 = df[['Price','Power(kwh)','Mileage(km)']]
print(data1.head())
# Out:
#     Price  Power(kwh)  Mileage(km)
# 45  27999     1.95000           25
# 23  34999     0.22896           25
# 24  34999     0.22896           25
# 25  39999     0.22896           25
# 26  42999     0.23040           25

# %%
corr = data1.corr()
sn.heatmap(corr, annot = True)
# Out:
# <AxesSubplot: >

# %%
data2 = df[['Price','Power(kwh)','Mileage(km)']]

# %%
data2.head()
# Out:
#     Price  Power(kwh)  Mileage(km)
# 45  27999     1.95000           25
# 23  34999     0.22896           25
# 24  34999     0.22896           25
# 25  39999     0.22896           25
# 26  42999     0.23040           25

# %%
data2["Brand_Cat"] = pd.factorize(df.Brand)[0]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11528\3611595604.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["Brand_Cat"] = pd.factorize(df.Brand)[0]

# %%
data2.head()
# Out:
#     Price  Power(kwh)  Mileage(km)  Brand_Cat
# 45  27999     1.95000           25          0
# 23  34999     0.22896           25          1
# 24  34999     0.22896           25          1
# 25  39999     0.22896           25          1
# 26  42999     0.23040           25          1

# %%
data2.Brand_Cat.value_counts()
# Out:
# 1    18
# 0     8
# 2     6
# 3     3
# 4     3
# 7     3
# 5     2
# 8     2
# 6     1
# Name: Brand_Cat, dtype: int64

# %%
corr = data2.corr()
sn.heatmap(corr, annot = True)
# Out:
# <AxesSubplot: >

# %%
x = data2['Power(kwh)']
y = data2['Price']

#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b, color = 'red')

# %%
x = data2['Mileage(km)']
y = data2['Price']

#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b, color = 'red')

# %% [markdown]
# # PCA have to be done at last

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df3 = pd.read_excel("Data/MainFileExcel.xlsx")

# %%
df3.head()
# Out:
#             ModelName   Brand     Type   Price  Power(kwh)  Mileage(km)
# 0              Ola S1     Ola  Scooter  129000        3.00        128.0
# 1  TVS iQube Electric     TVS  Scooter  161000        3.04        100.0
# 2          Ather 450X   Ather  Scooter  146000        3.70        165.0
# 3          Ola S1 Pro     Ola  Scooter  139000        4.00        181.0
# 4          Simple One  Simple  Scooter  145000        5.00        212.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ModelName    145 non-null    object
#  1   Brand        145 non-null    object
#  2   Type         145 non-null    object
#  3   Price        145 non-null    int64
#  4   Power(kwh)   145 non-null    float64
#  5   Mileage(km)  145 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 6.9+ KB

# %%
df3["Brand_Cat"] = pd.factorize(df3.Brand)[0]
df3["Type_Cat"] = pd.factorize(df3.Type)[0]

# %%
df3.head()
# Out:
#             ModelName   Brand     Type   Price  Power(kwh)  Mileage(km)  \
# 0              Ola S1     Ola  Scooter  129000        3.00        128.0
# 1  TVS iQube Electric     TVS  Scooter  161000        3.04        100.0
# 2          Ather 450X   Ather  Scooter  146000        3.70        165.0
# 3          Ola S1 Pro     Ola  Scooter  139000        4.00        181.0
# 4          Simple One  Simple  Scooter  145000        5.00        212.0
#
#    Brand_Cat  Type_Cat
# 0          0         0
# 1          1         0
# 2          2         0
# 3          0         0
# 4          3         0

# %%
corr = df3.corr()
sn.heatmap(corr, annot = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11528\1302688703.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df3.corr()
# <AxesSubplot: >

# %%
data3 = df3.iloc[:,3:-1]

# %%
data3.head()
# Out:
#     Price  Power(kwh)  Mileage(km)  Brand_Cat
# 0  129000        3.00        128.0          0
# 1  161000        3.04        100.0          1
# 2  146000        3.70        165.0          2
# 3  139000        4.00        181.0          0
# 4  145000        5.00        212.0          3

# %%
data3.describe()
# Out:
#               Price  Power(kwh)  Mileage(km)   Brand_Cat
# count  1.450000e+02  145.000000   145.000000  145.000000
# mean   1.403099e+06   14.085655   152.980690   31.055172
# std    3.748336e+06   27.083913   152.259195   20.454821
# min    2.499900e+04    0.040000    25.000000    0.000000
# 25%    4.500000e+04    0.580000    60.000000    9.000000
# 50%    8.699900e+04    2.280000   100.000000   33.000000
# 75%    1.800000e+05    4.320000   181.000000   48.000000
# max    1.950000e+07  107.000000   857.000000   67.000000

# %%
data3 = df3.iloc[:,3:8]

# %%
print(data3)
# Out:
#        Price  Power(kwh)  Mileage(km)  Brand_Cat  Type_Cat
# 0     129000        3.00        128.0          0         0
# 1     161000        3.04        100.0          1         0
# 2     146000        3.70        165.0          2         0
# 3     139000        4.00        181.0          0         0
# 4     145000        5.00        212.0          3         0
# ..       ...         ...          ...        ...       ...
# 140  1649000       40.50        453.0         66         3
# 141  1449000       30.20        312.0         66         3
# 142   869000       19.20        315.0         66         3
# 143  1249000       26.00        315.0         66         3
# 144  5690000       78.00        418.0         67         3
#
# [145 rows x 5 columns]

# %%
wcss = []
for i in range(1,11):
   model = KMeans(n_clusters = i, init = "k-means++")
   model.fit(data3)
   wcss.append(model.inertia_)
plt.figure(figsize=(10,10))
plt.plot(range(1,11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Standardize the data to have a mean of ~0 and a variance of 1
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(data3)
# Create a PCA instance: pca
pca = PCA(n_components=4)
principalComponents = pca.fit_transform(X_std)
# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_)
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Save components to a DataFrame
PCA_components = pd.DataFrame(principalComponents)

# %%
plt.scatter(PCA_components[0], PCA_components[1], alpha=.1, color='red')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
# Out:
# Text(0, 0.5, 'PCA 2')

# %%
wcss = {}
for i in range(1, 11):
	kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
	kmeans.fit(x)
	wcss[i] = kmeans.inertia_
	
plt.plot(wcss.keys(), wcss.values(), 'gs-')
plt.xlabel("Values of 'k'")
plt.ylabel('WCSS')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 4
#       2 for i in range(1, 11):
#       3 	kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
# ----> 4 	kmeans.fit(x)
#       5 	wcss[i] = kmeans.inertia_
#       7 plt.plot(wcss.keys(), wcss.values(), 'gs-')
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1390 """Compute k-means clustering.
#    1391
#    1392 Parameters
#    (...)
#    1413     Fitted estimator.
#    1414 """
#    1415 self._validate_params()
# -> 1417 X = self._validate_data(
#    1418     X,
#    1419     accept_sparse="csr",
#    1420     dtype=[np.float64, np.float32],
#    1421     order="C",
#    1422     copy=self.copy_x,
#    1423     accept_large_sparse=False,
#    1424 )
# ...

# %%
pca=PCA(n_components=2)
 
reduced_X=pd.DataFrame(data=pca.fit_transform(x),columns=['PCA1','PCA2'])
 
#Reduced Features
reduced_X.head()
# Out:
#            PCA1       PCA2
# 0 -1.274099e+06   9.165378
# 1 -1.242099e+06 -19.537630
# 2 -1.257099e+06  45.659149
# 3 -1.264099e+06  61.661081
# 4 -1.258099e+06  92.599997

# %%
centers=pca.transform(kmeans.cluster_centers_)

# reduced centers
centers
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# array([[ 2.57823417e+06,  3.27275760e+02],
#        [-1.30596772e+06, -2.22615761e+01],
#        [ 1.46635675e+07, -2.67415829e+01],
#        [ 8.67190083e+06,  8.20155799e+00],
#        [ 1.79969008e+07, -1.74205079e+02],
#        [ 4.27523417e+06,  1.92431897e+02],
#        [-2.18224168e+05,  1.36938221e+02],
#        [ 1.05969008e+07, -1.68852907e+02],
#        [ 6.01690083e+06,  1.35140621e+02],
#        [ 1.14256750e+06,  1.43210679e+02]])

# %%
plt.figure(figsize=(7,5))

# Scatter plot
plt.scatter(reduced_X['PCA1'],reduced_X['PCA2'],c=kmeans.labels_)
plt.scatter(centers[:,0],centers[:,1],marker='x',s=100,c='red')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Cluster')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       1 plt.figure(figsize=(7,5))
#       3 # Scatter plot
# ----> 4 plt.scatter(reduced_X['PCA1'],reduced_X['PCA2'],c=kmeans.labels_)
#       5 plt.scatter(centers[:,0],centers[:,1],marker='x',s=100,c='red')
#       6 plt.xlabel('PCA1')
#
# NameError: name 'reduced_X' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_wine
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
plt.figure(figsize=(7,5))
 
# Scatter plot
plt.scatter(PCA_components[0], PCA_components[1],c=kmeans.labels_)
plt.scatter(centers[:,0],centers[:,1],marker='x',s=100,c='red')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Wine Cluster')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 4
#       1 plt.figure(figsize=(7,5))
#       3 # Scatter plot
# ----> 4 plt.scatter(PCA_components[0], PCA_components[1],c=kmeans.labels_)
#       5 plt.scatter(centers[:,0],centers[:,1],marker='x',s=100,c='red')
#       6 plt.xlabel('PCA1')
#
# AttributeError: 'KMeans' object has no attribute 'labels_'

# %%
pca = PCA(2)
data = pca.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 pca = PCA(2)
# ----> 2 data = pca.fit_transform(x)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:462, in PCA.fit_transform(self, X, y)
# ...
